# %%
import pandas as pd
import re

# itertools — Functions creating iterators for efficient looping
# The module standardizes a core set of fast, memory efficient tools that are useful by themselves or in combination. 
from itertools import product,combinations

# %% [markdown]
# [itertools](https://docs.python.org/3/library/itertools.html)

# %%
file_path = 'test_data/corpus-q3.csv'
df = pd.read_csv(file_path)
df
# Out:
#                                                   gr  \
# 0  IMPROVISAÇÃO GRAVAR BANDA AJUDAR ESTIMULAR PRO...
# 1          EU PODER NUNCA MAIS VER VOCÊ NOVO [PONTO]
# 2  TER TODO RIQUEZA MUNDO PARA DAR # NEM SABER CO...
# 3               IDEIA ELE SER MELHOR QUE SEU [PONTO]
# 4                      TOM BEBER MAIS QUE EU [PONTO]
# 5                  EU SER MAIS VELHO QUE TOM [PONTO]
#
#                                                   gi
# 0  IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1S_AJUDAR_2S ...
# 1  PODER&POSSIBILIDADE NUNCA MAIS&SOMAR 1S_VER_2S...
# 2  TER TODO RIQUEZA MUNDO 1S_DAR_2S ELES NÃO_SABE...
# 3             IDEIA DELA MELHOR 3S_DO_QUE_2S [PONTO]
# 4     TOM BEBER MAIS&QUANTIDADE 3S_DO_QUE_1S [PONTO]
# 5         MAIS&QUANTIDADE VELHO 1S_DO_QUE_3S [PONTO]

# %%
# Persons of verbs
# [1-3][SP] = [(eu,nós),(tu,vós),(ele,eles)]

nums = ['1','2','3']
lts = ['S','P']

combinations = product(nums,lts, repeat=1)
combinations = product(combinations, repeat=2)

# Toal combinations for directionality augmentation
mylist = []
for i in combinations:
    
    left = i[0][0]+i[0][1] #left side of the verb
    rigth = i[1][0]+i[1][1] #rigth side of the verb
    
    mylist.append((left,rigth))

# %%
def directionality_augmentation(tuple_string):
    '''Directionality augmentation of phrase gi, miss gr'''
    
    # Lembrar de não usar \w , substituir por: REGEX_LATIN = 'A-ZÁÉÍÓÚÀÂÊÔÃÕÜÇa-záéíóúàâêôãõüç'
    w ='[A-ZÁÉÍÓÚÀÂÊÔÃÕÜÇa-záéíóúàâêôãõüç]+'

    pattern1 = '[1-3][SP](_'+w+'_)[1-3][SP]'
    pattern2 = '[1-3][SP]_'+w+'_[1-3][SP]'

    x = re.findall(pattern1,tuple_string[1])

    left_verb = re.findall('(.+)'+pattern2,
                           tuple_string[1])#pegando o lado esquerdo do verbo

    right_verb = re.findall(pattern2+'(.+)',
                            tuple_string[1])#pegando o lado direito do verbo

    result_all = []
    for person in mylist:
        verb = person[0] + x[0] + person[1]

        result_all.append(left_verb[0] + verb[0] + right_verb[0])
        
    return result_all

# %%
tuple_string = (df['gr'][0],df['gi'][0])

directionality_augmentation(tuple_string)
# Out:
# ['IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]']

# %% [markdown]
# ### Temos o seguinte problema. Além de gerar as novas frases do [gi] também temos que gerar para [gr].

# %% [markdown]
# <h2>TODO</h2>

# %%
import re
from itertools import product, combinations

regex_latin ='[A-ZÁÉÍÓÚÀÂÊÔÃÕÜÇa-záéíóúàâêôãõüç]+'

# agentes
agent_pattern = r'\b(EU|TU|ELE|ELA|NÓS|VÓS|ELES|ELAS)\b'


agents_dict = {

    '1S': ['EU'],
    '2S': ['TU'], 
    '3S': ['ELE', 'ELA'],
    '1P': ['NÓS'],
    '2P': ['VÓS'],
    '3P': ['ELES', 'ELAS']

}
# verbos
verb_pattern = r'\b({0}R)\b'.format(regex_latin)
# pronome obliquo atono
pronoun_pattern = r'\b(ME|TE|LHE|VOS|NOS|LHES)\b'

pronouns_dict = {

    '1S': ['ME'],
    '2S': ['TE'],
    '3S': ['LHE'],
    '1P': ['NOS'],
    '2P': ['VOS'],
    '3P': '[LHES']

}

pattern_agent_verb = "%s %s %s" %(agent_pattern, verb_pattern, agent_pattern)
pattern_pronoun_verb = "%s %s %s" %(agent_pattern, pronoun_pattern, verb_pattern)

phrases = ['EU ME REMEXER MUITO', 'OI EU ABRAÇAR TU PASSARO TU TRABALHAR EU QUIMO', 'NOSSA EU ABRAÇÉRAAR ELE BALEIA', 'COALA CAPIM EU ABRAÇAR VÓS ANIMAL']

behind_ahead = r'(.+){0}(.+)'.format(pattern_agent_verb)
search_pattern_agent_verb = re.findall(pattern_agent_verb, phrases[1])
search_results = re.finditer(behind_ahead, phrases[1])

#print(search_pattern_agent_verb[0])

list_new_phrases_s = []
list_new_phrases_noun = []
# Out:
#   File "<ipython-input-17-93c20fb67b99>", line 32
#     '3P': '[LHES']
#                  ^
# SyntaxError: invalid syntax

# %%
phrases = ['OI EU ABRAÇAR TU PASSARO QUIMO']
for phrase in phrases:

  # resultado do regex para o padrão [agente -> verbo -> receptor]
  search_pattern_agent_verb = re.findall(pattern_agent_verb, phrase)
    
  # resultado do regex para o padrão [agente -> pronome -> verbo]
  search_pattern_pronoun_verb = re.findall(pattern_pronoun_verb, phrase)
  #print("--> ", search_pattern_agent_verb)

  if search_pattern_agent_verb:
    # para cada padrão encontrado na frase
    for patterns_in_phrase in range(len(search_pattern_agent_verb)):
          
      # TODO: vou receber uma frase no padrão [('EU', 'ABRAÇAR', 'TU'), ('TU', 'TRABALHAR', 'EU')], fazer um regex para 
      # TODO: reconhecer o padrão do search_pattern_agent_verb e agrupar em look-behind e look-ahead, e estes serao usados 
      # TODO: na criação da frase tratada
      
      '''Transformando a padrão em search_pattern_agent_verb em string para pesquisar a parte de trás e da frente do padrão'''
      string = ''
      for index, part in enumerate(search_pattern_agent_verb[patterns_in_phrase]):
          if not index:
            string +=part
          else:
              string += ' '+part
      
      # padrão para o reconhecimento das partes de trás e da frente do padrão 
      ###behind_ahead = r'(.+){0}(.+)'.format(pattern_agent_verb)
      behind_ahead = r'(.+){0}(.+)'.format(string)

      behind_ahead_results = re.findall(behind_ahead, phrase)
      #print("behind_ahead<-- ", behind_ahead_results)

      # partes de trás
      before_pattern = behind_ahead_results[0][0]
      # verbo
      verb = search_pattern_agent_verb[patterns_in_phrase][1]
      # parte após o padrão 
      after_pattern = behind_ahead_results[0][-1]

      # combinação com todos as possibilidades do dicionário
      combinations = product(agents_dict.keys(), agents_dict.keys(), repeat=1)

      for item in combinations:
        # criação de frases do tipo [1S, 2S ...]
        list_new_phrases_s.append(f'{before_pattern} {item[0]} {verb} {item[1]} {after_pattern}')

        # criação de frases do tipo [EU, TU ...]
        # os for's são necessários nos casos de [ELE, ELA, ELES ELAS]
        for index_1, item_1  in enumerate(agents_dict[item[0]]):

          for index_2, item_2 in enumerate(agents_dict[item[1]]):

            list_new_phrases_noun.append(f'{before_pattern}{item_1} {verb} {item_2}{after_pattern}')

    #elif search_pattern_pronoun_verb:
for item in list_new_phrases_noun:
    print(item)
print(len(list_new_phrases_noun))
# Out:
# OI EU ABRAÇAR EU PASSARO QUIMO
# OI EU ABRAÇAR TU PASSARO QUIMO
# OI EU ABRAÇAR ELE PASSARO QUIMO
# OI EU ABRAÇAR ELA PASSARO QUIMO
# OI EU ABRAÇAR NÓS PASSARO QUIMO
# OI EU ABRAÇAR VÓS PASSARO QUIMO
# OI EU ABRAÇAR ELES PASSARO QUIMO
# OI EU ABRAÇAR ELAS PASSARO QUIMO
# OI TU ABRAÇAR EU PASSARO QUIMO
# OI TU ABRAÇAR TU PASSARO QUIMO
# OI TU ABRAÇAR ELE PASSARO QUIMO
# OI TU ABRAÇAR ELA PASSARO QUIMO
# OI TU ABRAÇAR NÓS PASSARO QUIMO
# OI TU ABRAÇAR VÓS PASSARO QUIMO
# OI TU ABRAÇAR ELES PASSARO QUIMO
# OI TU ABRAÇAR ELAS PASSARO QUIMO
# OI ELE ABRAÇAR EU PASSARO QUIMO
# OI ELA ABRAÇAR EU PASSARO QUIMO
# OI ELE ABRAÇAR TU PASSARO QUIMO
# OI ELA ABRAÇAR TU PASSARO QUIMO
# OI ELE ABRAÇAR ELE PASSARO QUIMO
# OI ELE ABRAÇAR ELA PASSARO QUIMO
# OI ELA ABRAÇAR ELE PASSARO QUIMO
# OI ELA ABRAÇAR ELA PASSARO QUIMO
# OI ELE ABRAÇAR NÓS PASSARO QUIMO
# OI ELA ABRAÇAR NÓS PASSARO QUIMO
# OI ELE ABRAÇAR VÓS PASSARO QUIMO
# OI ELA ABRAÇAR VÓS PASSARO QUIMO
# OI ELE ABRAÇAR ELES PASSARO QUIMO
# OI ELE ABRAÇAR ELAS PASSARO QUIMO
# OI ELA ABRAÇAR ELES PASSARO QUIMO
# OI ELA ABRAÇAR ELAS PASSARO QUIMO
# OI NÓS ABRAÇAR EU PASSARO QUIMO
# OI NÓS ABRAÇAR TU PASSARO QUIMO
# OI NÓS ABRAÇAR ELE PASSARO QUIMO
# OI NÓS ABRAÇAR ELA PASSARO QUIMO
# OI NÓS ABRAÇAR NÓS PASSARO QUIMO
# OI NÓS ABRAÇAR VÓS PASSARO QUIMO
# OI NÓS ABRAÇAR ELES PASSARO QUIMO
# OI NÓS ABRAÇAR ELAS PASSARO QUIMO
# OI VÓS ABRAÇAR EU PASSARO QUIMO
# OI VÓS ABRAÇAR TU PASSARO QUIMO
# OI VÓS ABRAÇAR ELE PASSARO QUIMO
# OI VÓS ABRAÇAR ELA PASSARO QUIMO
# OI VÓS ABRAÇAR NÓS PASSARO QUIMO
# OI VÓS ABRAÇAR VÓS PASSARO QUIMO
# OI VÓS ABRAÇAR ELES PASSARO QUIMO
# OI VÓS ABRAÇAR ELAS PASSARO QUIMO
# OI ELES ABRAÇAR EU PASSARO QUIMO
# OI ELAS ABRAÇAR EU PASSARO QUIMO
# OI ELES ABRAÇAR TU PASSARO QUIMO
# OI ELAS ABRAÇAR TU PASSARO QUIMO
# OI ELES ABRAÇAR ELE PASSARO QUIMO
# OI ELES ABRAÇAR ELA PASSARO QUIMO
# OI ELAS ABRAÇAR ELE PASSARO QUIMO
# OI ELAS ABRAÇAR ELA PASSARO QUIMO
# OI ELES ABRAÇAR NÓS PASSARO QUIMO
# OI ELAS ABRAÇAR NÓS PASSARO QUIMO
# OI ELES ABRAÇAR VÓS PASSARO QUIMO
# OI ELAS ABRAÇAR VÓS PASSARO QUIMO
# OI ELES ABRAÇAR ELES PASSARO QUIMO
# OI ELES ABRAÇAR ELAS PASSARO QUIMO
# OI ELAS ABRAÇAR ELES PASSARO QUIMO
# OI ELAS ABRAÇAR ELAS PASSARO QUIMO
# OI EU ABRAÇAR EU PASSARO QUIMO
# OI EU ABRAÇAR TU PASSARO QUIMO
# OI EU ABRAÇAR ELE PASSARO QUIMO
# OI EU ABRAÇAR ELA PASSARO QUIMO
# OI EU ABRAÇAR NÓS PASSARO QUIMO
# OI EU ABRAÇAR VÓS PASSARO QUIMO
# OI EU ABRAÇAR ELES PASSARO QUIMO
# OI EU ABRAÇAR ELAS PASSARO QUIMO
# OI TU ABRAÇAR EU PASSARO QUIMO
# OI TU ABRAÇAR TU PASSARO QUIMO
# OI TU ABRAÇAR ELE PASSARO QUIMO
# OI TU ABRAÇAR ELA PASSARO QUIMO
# OI TU ABRAÇAR NÓS PASSARO QUIMO
# OI TU ABRAÇAR VÓS PASSARO QUIMO
# OI TU ABRAÇAR ELES PASSARO QUIMO
# OI TU ABRAÇAR ELAS PASSARO QUIMO
# OI ELE ABRAÇAR EU PASSARO QUIMO
# OI ELA ABRAÇAR EU PASSARO QUIMO
# OI ELE ABRAÇAR TU PASSARO QUIMO
# OI ELA ABRAÇAR TU PASSARO QUIMO
# OI ELE ABRAÇAR ELE PASSARO QUIMO
# OI ELE ABRAÇAR ELA PASSARO QUIMO
# OI ELA ABRAÇAR ELE PASSARO QUIMO
# OI ELA ABRAÇAR ELA PASSARO QUIMO
# OI ELE ABRAÇAR NÓS PASSARO QUIMO
# OI ELA ABRAÇAR NÓS PASSARO QUIMO
# OI ELE ABRAÇAR VÓS PASSARO QUIMO
# OI ELA ABRAÇAR VÓS PASSARO QUIMO
# OI ELE ABRAÇAR ELES PASSARO QUIMO
# OI ELE ABRAÇAR ELAS PASSARO QUIMO
# OI ELA ABRAÇAR ELES PASSARO QUIMO
# OI ELA ABRAÇAR ELAS PASSARO QUIMO
# OI NÓS ABRAÇAR EU PASSARO QUIMO
# OI NÓS ABRAÇAR TU PASSARO QUIMO
# OI NÓS ABRAÇAR ELE PASSARO QUIMO
# OI NÓS ABRAÇAR ELA PASSARO QUIMO
# OI NÓS ABRAÇAR NÓS PASSARO QUIMO
# OI NÓS ABRAÇAR VÓS PASSARO QUIMO
# OI NÓS ABRAÇAR ELES PASSARO QUIMO
# OI NÓS ABRAÇAR ELAS PASSARO QUIMO
# OI VÓS ABRAÇAR EU PASSARO QUIMO
# OI VÓS ABRAÇAR TU PASSARO QUIMO
# OI VÓS ABRAÇAR ELE PASSARO QUIMO
# OI VÓS ABRAÇAR ELA PASSARO QUIMO
# OI VÓS ABRAÇAR NÓS PASSARO QUIMO
# OI VÓS ABRAÇAR VÓS PASSARO QUIMO
# OI VÓS ABRAÇAR ELES PASSARO QUIMO
# OI VÓS ABRAÇAR ELAS PASSARO QUIMO
# OI ELES ABRAÇAR EU PASSARO QUIMO
# OI ELAS ABRAÇAR EU PASSARO QUIMO
# OI ELES ABRAÇAR TU PASSARO QUIMO
# OI ELAS ABRAÇAR TU PASSARO QUIMO
# OI ELES ABRAÇAR ELE PASSARO QUIMO
# OI ELES ABRAÇAR ELA PASSARO QUIMO
# OI ELAS ABRAÇAR ELE PASSARO QUIMO
# OI ELAS ABRAÇAR ELA PASSARO QUIMO
# OI ELES ABRAÇAR NÓS PASSARO QUIMO
# OI ELAS ABRAÇAR NÓS PASSARO QUIMO
# OI ELES ABRAÇAR VÓS PASSARO QUIMO
# OI ELAS ABRAÇAR VÓS PASSARO QUIMO
# OI ELES ABRAÇAR ELES PASSARO QUIMO
# OI ELES ABRAÇAR ELAS PASSARO QUIMO
# OI ELAS ABRAÇAR ELES PASSARO QUIMO
# OI ELAS ABRAÇAR ELAS PASSARO QUIMO
# 128
