# %%
import pandas as pd
import re

# itertools — Functions creating iterators for efficient looping
# The module standardizes a core set of fast, memory efficient tools that are useful by themselves or in combination. 
from itertools import product,combinations

# %% [markdown]
# [itertools](https://docs.python.org/3/library/itertools.html)

# %%
file_path = 'test_data/corpus-q3.csv'
df = pd.read_csv(file_path)
df
# Out:
#                                                   gr  \
# 0  IMPROVISAÇÃO GRAVAR BANDA AJUDAR ESTIMULAR PRO...
# 1          EU PODER NUNCA MAIS VER VOCÊ NOVO [PONTO]
# 2  TER TODO RIQUEZA MUNDO PARA DAR # NEM SABER CO...
# 3               IDEIA ELE SER MELHOR QUE SEU [PONTO]
# 4                      TOM BEBER MAIS QUE EU [PONTO]
# 5                  EU SER MAIS VELHO QUE TOM [PONTO]
#
#                                                   gi
# 0  IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1S_AJUDAR_2S ...
# 1  PODER&POSSIBILIDADE NUNCA MAIS&SOMAR 1S_VER_2S...
# 2  TER TODO RIQUEZA MUNDO 1S_DAR_2S ELES NÃO_SABE...
# 3             IDEIA DELA MELHOR 3S_DO_QUE_2S [PONTO]
# 4     TOM BEBER MAIS&QUANTIDADE 3S_DO_QUE_1S [PONTO]
# 5         MAIS&QUANTIDADE VELHO 1S_DO_QUE_3S [PONTO]

# %%
# Persons of verbs
# [1-3][SP] = [(eu,nós),(tu,vós),(ele,eles)]

nums = ['1','2','3']
lts = ['S','P']

combinations = product(nums,lts, repeat=1)
combinations = product(combinations, repeat=2)

# Toal combinations for directionality augmentation
mylist = []
for i in combinations:
    
    left = i[0][0]+i[0][1] #left side of the verb
    rigth = i[1][0]+i[1][1] #rigth side of the verb
    
    mylist.append((left,rigth))

# %%
def directionality_augmentation(tuple_string):
    '''Directionality augmentation of phrase gi, miss gr'''
    
    # Lembrar de não usar \w , substituir por: REGEX_LATIN = 'A-ZÁÉÍÓÚÀÂÊÔÃÕÜÇa-záéíóúàâêôãõüç'
    w ='[A-ZÁÉÍÓÚÀÂÊÔÃÕÜÇa-záéíóúàâêôãõüç]+'

    pattern1 = '[1-3][SP](_'+w+'_)[1-3][SP]'
    pattern2 = '[1-3][SP]_'+w+'_[1-3][SP]'

    x = re.findall(pattern1,tuple_string[1])

    left_verb = re.findall('(.+)'+pattern2,
                           tuple_string[1])#pegando o lado esquerdo do verbo

    right_verb = re.findall(pattern2+'(.+)',
                            tuple_string[1])#pegando o lado direito do verbo

    result_all = []
    for person in mylist:
        verb = person[0] + x[0] + person[1]

        result_all.append(left_verb[0] + verb[0] + right_verb[0])
        
    return result_all

# %%
tuple_string = (df['gr'][0],df['gi'][0])

directionality_augmentation(tuple_string)
# Out:
# ['IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 1 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 2 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]',
#  'IMPROVISAR GRAVAÇÃO BANDA&MÚSICA 3 ESTIMULAR CRIATIVO DEPOIS DOIS SEMANA TER SESSENTA E CINCO MÚSICA [PONTO]']

# %% [markdown]
# ### Temos o seguinte problema. Além de gerar as novas frases do [gi] também temos que gerar para [gr].

# %% [markdown]
# <h2>TODO</h2>

# %%
import re
from itertools import product, combinations

# agentes
regex_latin ='[A-ZÁÉÍÓÚÀÂÊÔÃÕÜÇa-záéíóúàâêôãõüç]+'

agent_pattern = r'\b(EU|TU|ELE|ELA|NÓS|VÓS|ELES|ELAS)\b'

agents_dict = {

    # 'EU': '1S',
    # 'TU': '2S',
    # 'ELE': '3S',
    # 'ELA': '3S',
    # 'NÓS': '1P',
    # 'VÓS': '2P',
    # 'ELES': '3P',
    # 'ELAS': '3P',
    '1S': 'EU',
    '2S': 'TU', 
    '3S': ['ELE', 'ELA'],
    '1P': 'NÓS',
    '2P': 'VÓS',
    '3P': ['ELES', 'ELAS']

}
# verbos
verb_pattern = r'\b({0}R)\b'.format(regex_latin)
# pronome obliquo atono
pronoun_pattern = r'\b(ME|TE|LHE|VOS|NOS|LHES)\b'

pronouns_dict = {

    'ME': '1S',
    'TE': '2S',
    'LHE':'3S',
    'NOS': '1P',
    'VOS': '2P',
    'LHES': '3P',
    '1S': 'ME',
    '2S': 'TE',
    '3S': 'LHE',
    '1P': 'NOS',
    '2P': 'VOS',
    '3P': 'LHES'

}

pattern_agent_verb = "%s %s %s" %(agent_pattern, verb_pattern, agent_pattern)
pattern_pronoun_verb = "%s %s %s" %(agent_pattern, pronoun_pattern, verb_pattern)

phrases = ['EU ME REMEXER MUITO', 'OI EU ABRAÇAR TU PASSARO TU TRABALHAR EU QUIMO', 'NOSSA EU ABRAÇÉRAAR ELE BALEIA', 'COALA CAPIM EU ABRAÇAR VÓS ANIMAL']

behind_ahead = r'(.+){0}(.+)'.format(pattern_agent_verb)
search_results = re.findall(behind_ahead, phrases[3])
print(search_results[0][0])

list_new_phrases_s = []
list_new_phrases_noun = []

for phrase in phrases:

    search_pattern_agent_verb = re.findall(pattern_agent_verb, phrase)
    
    search_pattern_pronoun_verb = re.findall(pattern_pronoun_verb, phrase)

    if search_pattern_agent_verb:

        behind_ahead = r'(.+){0}(.+)'.format(pattern_agent_verb)

        behind_ahead_results = re.findall(behind_ahead, phrase)

        before_pattern = behind_ahead_results[0][0]
        verb = search_pattern_agent_verb[0][1]
        after_pattern = behind_ahead_results[0][-1]
        
        combinations = product(agents_dict.keys(), agents_dict.keys(), repeat=1)

        for item in combinations:

            list_new_phrases_s.append(f'{before_pattern} {item[0]} {verb} {item[1]} {after_pattern}')

            #list_new_phrases_s.append(f'{behind_ahead_results[0][0]}{item[0]} {search_pattern_agent_verb[0][1]} {item[1]}{behind_ahead_results[0][-1]}')

            # list_new_phrases_noun.append(agents_dict[behind_ahead_results[0][0]] + item[0] + " "
            # + search_pattern_agent_verb[0][1] + " " + item[1] + agents_dict[behind_ahead_results[0][-1]])


            

    
    #if search_pattern_pronoun_verb:
        
    #    print(search_pattern_pronoun_verb)

    # search_pattern_agent_verb = re.findall(r'')

    # if search_pattern_agent_verb:
    #     for val in search_pattern_agent_verb:
    #         print(val)

for item in list_new_phrases_s:
    print(item)

# for item in combinations:
#     print(item)
# Out:
# COALA CAPIM
# OI EU ABRAÇAR TU PASSARO 1S ABRAÇAR 1S QUIMO
# OI EU ABRAÇAR TU PASSARO 1S ABRAÇAR 2S QUIMO
# OI EU ABRAÇAR TU PASSARO 1S ABRAÇAR 3S QUIMO
# OI EU ABRAÇAR TU PASSARO 1S ABRAÇAR 1P QUIMO
# OI EU ABRAÇAR TU PASSARO 1S ABRAÇAR 2P QUIMO
# OI EU ABRAÇAR TU PASSARO 1S ABRAÇAR 3P QUIMO
# OI EU ABRAÇAR TU PASSARO 2S ABRAÇAR 1S QUIMO
